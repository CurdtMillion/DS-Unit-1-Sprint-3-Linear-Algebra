# %% [markdown]
# <a href="https://colab.research.google.com/github/CurdtMillion/DS-Unit-1-Sprint-3-Linear-Algebra/blob/master/DS_133_High_Dimensional_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
plt.rcParams.update({'font.size': 16})

# %%
# Plotting a line that does pass the vertical line test
x = np.arange(-10, 11)
y = x**4 - 5*x
plt.plot(x, y)
plt.title('This passes the vertical line test')
plt.axvline(x=0, color='r');

# %%
# Plotting a line that does NOT pass the vertical line test
x = y**2 + 3*y
y = np.arange(-10, 11)
plt.plot(x, y)
plt.title('This does not pass the vertical line test')
plt.axvline(x=25, color='r');

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %% [markdown]
# Graphs that don't pass the vertical line test are not considered 'functions', because a 'function' cannot have the same input (x value/domain value) mapped to multiple outputs (y value/co-domain value).

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %%
# Relation 1: {(1,2),(3,2),(1,3)}
x = np.array([1, 3, 1])
y = np.array([2, 2, 3])
plt.scatter(x, y, s=100)
plt.plot(x, y, color='g')
plt.title('Not a function, intersects v-line more than once.')
plt.axvline(x=2, color='red');

# THIS RELATION IS NOT A FUNCTION.

# %%
# Relation 2: {(1,3),(2,3),(6,7)}
x = np.array([1, 2, 6])
y = np.array([3, 3, 7])
plt.scatter(x, y, s=100)
plt.plot(x, y, color='g')
plt.title('This function is a relation; only intersects v-line once.')
plt.axvline(x=2, color='red');
# THIS RELATION IS A FUNCTION.

# %%
# Relation 3: {(9,4),(2,1),(9,6)}
x = np.array([9, 2, 9])
y = np.array([4, 1, 6])
plt.scatter(x, y, s=100)
plt.plot(x, y, color='g')
plt.title('Not a function, intersects v-line more than once.')
plt.axvline(x=6, color='red');
# THIS RELATION IS NOT A FUNCTION.

# %%
# Relation 4: {(6,2),(8,3),(6,4)}
x = np.array([6, 8, 6])
y = np.array([2, 3, 4])
plt.scatter(x, y, s=100)
plt.plot(x, y, color='g')
plt.title('Not a function, intersecst v-line more than once.')
plt.axvline(x=6.75, color='red');
# THIS RELATION IS NOT A FUNCTION.

# %%
# Relation 5: {(2,6),(2,7),(2,4)}
x = np.array([2, 2, 2])
y = np.array([6, 7, 4])
plt.scatter(x, y, s=100)
plt.plot(x, y, color='g')
plt.title('Relation graphs right on top of v-line, not a function.')
plt.axvline(x=2, color='red');
# THIS RELATION IS TRICKY, IN THAT THE VLINE CAN LAY ENTIRELY ON TOP OF OUR
# LINE.  THEREFORE, I WOULD SAY THIS IS NOT A FUNCTION.

# %%
# Relations 2 is the only one here that is a function because there are not repeated x values. 
# In other words, there are no two different y values that are mapped to by the same x value.

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %%
# m(x1, x2, x3) = (x1 + x2, x1 + x3, x2 + x3)
# This function has 3d input, and 3d output.

# %%
# n(x1, x2, x3, x4) = (x2**2 + x3, x2*x4)
# This function has 4d input, and 2d output.

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %%
# Yes this is possible. For more information on functions from lower dimensions of space that map to higher dimensions of space, 
# google the terms injective and surjective in relation to Linear Transformations:
#
# https://youtu.be/xKNX8BUWR0g

# Example would be:
# f(x)=(x,x+1)

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %%
import pandas as pd
import numpy as np

# %%
def p(vect):
  '''
  Takes 2d vector as input
  Outputs a 2d vector
  '''
  x1 = vect[0][0]
  x2 = vect[1][0]
  row1 = np.array([x1 + 3*x2])
  row2 = np.array([2*x2 - x1])
  output = np.array([row1, row2])
  return output

# %%
# Applying to x
j_hat = np.array([[1],[0]])
d = p(j_hat)
d
# Out:
# array([[ 1],
#        [-1]])

# %%
# Applying to y
jj_hat = np.array([[0],[1]])
e = p(jj_hat)
e
# Out:
# array([[3],
#        [2]])

# %%
# Turning into matrix
T = np.column_stack([d,e])
T
# Out:
# array([[ 1,  3],
#        [-1,  2]])

# %%
def q(vect):
  '''
  Takes 3d vector as input
  Outputs a 3d vector
  '''
  x1 = vect[0][0]
  x2 = vect[1][0]
  x3 = vect[2][0]
  row1 = np.array([4*x1 + x2 + 2*x3])
  row2 = np.array([2*x2 - x1 + 3*x3])
  row3 = np.array([5*x1 - 2*x3 + x2])
  output = np.array([row1, row2, row3])
  return output

# %%
# Applying to x
k_hat = np.array([[1],[0],[0]])
f = q(k_hat)
f
# Out:
# array([[ 4],
#        [-1],
#        [ 5]])

# %%
# Applying to y
l_hat = np.array([[0],[1],[0]])
g = q(l_hat)
g
# Out:
# array([[1],
#        [2],
#        [1]])

# %%
# Applying to z
m_hat = np.array([[0],[0],[1]])
h = q(m_hat)
h
# Out:
# array([[ 2],
#        [ 3],
#        [-2]])

# %%
# Turn this into a matrix
U = np.column_stack([f,g,h])
U
# Out:
# array([[ 4,  1,  2],
#        [-1,  2,  3],
#        [ 5,  1, -2]])

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
# Transformation Matrix to verify T
T1 = np.array([[1,3], [-1,2]])
# Input Vector
v1 = np.array([2,3])

# Found by hand
by_hand = [11, 4]

# Found with NumPy
np.matmul(T1, v1)
# Out:
# array([11,  4])

# %%
# Transformation Matrix to verify U
U1 = np.array([[4,1,2], [-1,2,3], [5,1,-2]])
# Input Vector
v2 = np.array([1,2,3])

# Found by Hand
by_hand2 = [12, 12, 1]

# Found with NumPy
np.matmul(U1, v2)
# Out:
# array([12, 12,  1])

# %% [markdown]
# The below code is me attempting this based off of the lecture/live coding notebook.

# %%
# Verifying for the first one
input_vector=np.array([[3],[4]])
p(input_vector)
# Out:
# array([[15],
#        [ 5]])

# %%
# Double checking for the first one
output_vector=np.matmul(T, input_vector)
output_vector
# Out:
# array([[15],
#        [ 5]])

# %%
# We got the same answer, now for the
# Second one
input_vector2=np.array([[3],[4],[5]])
q(input_vector2)
# Out:
# array([[26],
#        [20],
#        [ 9]])

# %%
output_vector2=np.matmul(T, input_vector2)
output_vector2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-07045b33a8e4> in <module>()
# ----> 1 output_vector2=np.matmul(T, input_vector2)
#       2 output_vector2
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 2)

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.

# %%
# Eigenvalues and eigenvectors are important, because they can be used to decompose and square matrix by diagonalizing it.

# %% [markdown]
# Further explanation:
# An eigenvector is a vector that does not change orientation (direction in which it is pointing) during a linear transformation. An eigenvector always comes paired with a corresponding eigenvalue. Every linear transformation has at least one eigenvector-eigenvalue pair. The eigenvalue describes how much the eigenvector gets scaled by (stretched or squished) during the transformation.

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?

# %%
# As you get more and more dimensions on your data frame, it becomes harder and harder to visualize it.

# %% [markdown]
# More in depth challenges after more research:
# Increased computational inefficiency (searching)
# Increased data redundancy with increasing number of columns.
# Measures of euclidean distance breaks down in high-dimensional spaces
# Increased sparcity of data.
# As the number of parameters in a model grows while number of available observations remains fixed, overfitting a predictive model becomes more certain.

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?

# %%
# I will need to come back to this question.
# Per research online, it seems that there is a 1 in 10 rule.

# %% [markdown]
# Additional info:
# You should have 5x as many observations (rows) as you do parameters (columns) in a machine learning model.

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Code for loading and cleaning the 2013 national dataset from the [Housing Affordability Data System (HADS)](https://www.huduser.gov/portal/datasets/hads/hads.html) --housing data, can be found below.
#
# ## Perform PCA on the processed dataset `national_processed` (Make sure you standardize your data!) and then make a scatterplot of PC1 against PC2. Some of our discussion and work around PCA with this dataset will continue during tomorrow's lecture and assignment.
#
# Not only does this dataset have decent amount columns to begin with (99), but in preparing the data for PCA we have also [one-hot-encoded](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f#targetText=One%20hot%20encoding%20is%20a,the%20entry%20in%20the%20dataset.) all of the categorical variables. This has the effect of creating a new column for each individual category of each categorical variable. After processing this dataset has 64738 columns. --Das a lot of columns.
#
# Don't worry too much about the mechanics of one-hot encoding right now, you will learn and experiment with a whole bunch of categorical encoding approaches in unit 2.
#
# The code below will read in the dataset and perform the one-hot encoding of the categorical variables. Start adding your PCA code at the bottom of the provided code.

# %%
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read Natinal Data 
national_url = 'https://www.huduser.gov/portal/datasets/hads/hads2013n_ASCII.zip'
national_file = 'thads2013n.txt'

if os.path.exists(national_file):
    national = pd.read_csv(national_file)
else: 
    z_national = urlopen(national_url)
    zip_national = ZipFile(BytesIO(z_national.read())).extract(national_file)
    national = pd.read_csv(zip_national)

print(national.shape)
national.head()
# Out:
# (64535, 99)
#           CONTROL  AGE1 METRO3  ...          FMTBURDEN  FMTREGION  FMTSTATUS
# 0  '100003130103'    82    '3'  ...     '2 30% to 50%'       '-5'       '-5'
# 1  '100006110249'    50    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 2  '100006370140'    53    '5'  ...    '3 50% or More'       '-5'       '-5'
# 3  '100006520140'    67    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 4  '100007130148'    26    '1'  ...  '1 Less than 30%'       '-5'       '-5'
#
# [5 rows x 99 columns]

# %%
# Look at datatypes
# a lot of object datatypes even though they seem to be strings of numbers.
national.dtypes
# Out:
# CONTROL            object
# AGE1                int64
# METRO3             object
# REGION             object
# LMED                int64
#                     ...
# FMTINCRELAMICAT    object
# FMTASSISTED        object
# FMTBURDEN          object
# FMTREGION          object
# FMTSTATUS          object
# Length: 99, dtype: object

# %%
# check for null values
national.isnull().sum().any()
# Out:
# False

# %%
# check for number of categorical vs numeric columns
cat_cols = national.columns[national.dtypes=='object']
num_cols = national.columns[national.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 32 categorical columns
# 67 numerical columns

# %%
# We're making a copy of our data in case we mess something up.
national_processed = national.copy()

# Categorically Encode our Variables:
# They need to all be numeric before we do PCA.
# https://pbpython.com/categorical-encoding.html

# Cast categorical columns to "category" data type
national_processed[cat_cols] = national_processed[cat_cols].astype('category')

national_processed.dtypes
# Out:
# CONTROL            category
# AGE1                  int64
# METRO3             category
# REGION             category
# LMED                  int64
#                      ...
# FMTINCRELAMICAT    category
# FMTASSISTED        category
# FMTBURDEN          category
# FMTREGION          category
# FMTSTATUS          category
# Length: 99, dtype: object

# %%
# Replace all category cell values with their numeric category codes
for col in cat_cols:
  national_processed[col] = national_processed[col].cat.codes

print(national_processed.shape)
national_processed.head(10)
# Out:
# (64535, 99)
#    CONTROL  AGE1  METRO3  REGION  ...  FMTASSISTED  FMTBURDEN  FMTREGION  FMTSTATUS
# 0        0    82       2       0  ...            0          2          0          0
# 1        1    50       4       2  ...            0          1          0          0
# 2        2    53       4       2  ...            0          3          0          0
# 3        3    67       4       2  ...            0          1          0          0
# 4        4    26       0       2  ...            1          1          0          0
# 5        5    56       1       2  ...            2          3          0          0
# 6        6    50       0       2  ...            0          1          0          0
# 7        7    26       3       3  ...            1          2          1          0
# 8        8    60       4       3  ...            0          1          1          0
# 9        9    26       3       1  ...            1          1          0          0
#
# [10 rows x 99 columns]

# %%
# Now we only have numeric columns (ints and floats)
national_processed.dtypes
# Out:
# CONTROL            int32
# AGE1               int64
# METRO3              int8
# REGION              int8
# LMED               int64
#                    ...
# FMTINCRELAMICAT     int8
# FMTASSISTED         int8
# FMTBURDEN           int8
# FMTREGION           int8
# FMTSTATUS           int8
# Length: 99, dtype: object

# %%
# Visualizing rooms and bedrooms compared to value
plt.scatter(national_processed['ROOMS'], national_processed['BEDRMS'], c=national_processed['VALUE'])
plt.xlabel('ROOMS')
plt.ylabel('BEDRMS');

# %%
# Why not show it in 3D?
# Comparing rooms and bedrooms and age against the value of the house.
from mpl_toolkits.mplot3d import Axes3D
plt.figure().gca(projection='3d')
plt.scatter(national_processed['ROOMS'], national_processed['BEDRMS'], national_processed['AGE1'], c=national_processed['VALUE'])
plt.xlabel('ROOMS')
plt.ylabel('BEDRMS');
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# Comparing age of house with number of rooms and value
# 2D plot
plt.scatter(national_processed['VALUE'], national_processed['ROOMS'], c=national_processed['AGE1'])
plt.xlabel('VALUE')
plt.ylabel('ROOMS');

# %%
# Start by standardizing data
from sklearn.preprocessing import StandardScaler
feature_cols=national_processed.columns[1:]
feature_cols[:5]
# I am assuming this is just checking the 5 columns to check dtype???
# Out:
# Index(['AGE1', 'METRO3', 'REGION', 'LMED', 'FMR'], dtype='object')

# %%
# This is where I am normalizing the features:
x = national_processed.loc[:, feature_cols].values
x = StandardScaler().fit_transform(x)

# %%
# Checking normalized data for a mean of zero and std of one.
print('{:.2f}'.format(np.mean(x)))
print(np.std(x))
# Out:
# 0.00
# 0.9948848769417227

# %%
# STD is pretty much 1, moving on.
# Convert the normalized features into its own DF:
normalized_national_processed = pd.DataFrame(x,columns=feature_cols)
normalized_national_processed.head(5)
# Out:
#        AGE1    METRO3    REGION  ...  FMTBURDEN  FMTREGION  FMTSTATUS
# 0  1.488075  0.608784 -1.327872  ...   0.549473  -0.462107        0.0
# 1  0.088812  2.184270  0.576698  ...  -0.544709  -0.462107        0.0
# 2  0.219993  2.184270  0.576698  ...   1.643655  -0.462107        0.0
# 3  0.832170  2.184270  0.576698  ...  -0.544709  -0.462107        0.0
# 4 -0.960634 -0.966702  0.576698  ...  -0.544709  -0.462107        0.0
#
# [5 rows x 98 columns]

# %%
# Importing PCA module from sklearn
from sklearn.decomposition import PCA

# %%
# Passing desired number of components
pca_national = PCA(n_components=2)

# %%
# fit_transform on aggregate data
pca_data = pca_national.fit_transform(x)

# %%
df_final = pd.DataFrame(data = pca_data, columns = ['comp_1', 'comp_2'])
df_final.head()
# Out:
#      comp_1    comp_2
# 0 -2.607484 -1.380332
# 1  2.010313 -0.992019
# 2  1.184849  0.366219
# 3  2.791772  1.719967
# 4 -1.600407 -0.882243

# %%
# Add back in the value of the house
df_final['VALUE']=national['VALUE']
df_final.sample(5)
# Out:
#          comp_1    comp_2   VALUE
# 52703  4.253607 -0.065484  250000
# 36568 -5.216779 -3.378659      -6
# 36733 -4.430327 -2.184439      -6
# 7159   2.011140  2.556996  220000
# 3924   2.628280  1.322951  200000

# %%
# Scatter plot of PC1 and PC2
plt.figure(figsize=(10,10))
plt.xlabel('Component 1')
plt.ylabel('Component 2')
for k, c in [(0, 'indigo'), (1, 'gold')]:
    subset=df_final[df_final['VALUE']==k]    
    plt.scatter(x=subset['comp_1'], 
                y=subset['comp_2'], 
                s=200,
                alpha=.5,
                color=c,
                label=k);
plt.legend();

# %% [markdown]
# # Stretch Goals
#
# ## 1) Perform further data exploration on the HADS national dataset (the version before we one-hot encoded it) Make scatterplots and see if you can see any resemblance between the original scatterplots and the plot of the principal components that you made in 7.1.
#
# (You may or may not not see very much resemblance depending on the variables you choose, and that's ok!)
#
# ## 2) Study "Scree Plots" and then try and make one for your PCA dataset. How many principal conponents do you need to retain in order for your PCs to contain 90% of the explained variance?
#
# We will present this topic formally at the beginning of tomorrow's lecture, so if you figure this stretch goal out, you're ahead of the game.
#
# ## 3) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# Prioritize self-study over this stretch goal if you are not semi-comfortable with the topics of PCA, Eigenvalues, and Eigenvectors.
#
# ![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
